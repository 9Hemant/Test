# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("facebook.csv")
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
df1 = df.dropna()

# %%
df1.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   0
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
df1['Type'] = df1['Type'].replace(['Photo'],1)
df1['Type'] = df1['Type'].replace(['Status'],0)
# Out:
# C:\Users\Shubham\AppData\Local\Temp\ipykernel_14408\862113152.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Type'] = df1['Type'].replace(['Photo'],1)
# C:\Users\Shubham\AppData\Local\Temp\ipykernel_14408\862113152.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Type'] = df1['Type'].replace(['Status'],0)

# %%
subset1 = df1.loc[0:10]
subset1
# Out:
#     Page total likes Type  Category  Post Month  Post Weekday  Post Hour  \
# 0             139441    1         2          12             4          3
# 1             139441    0         2          12             3         10
# 2             139441    1         3          12             3          3
# 3             139441    1         2          12             2         10
# 4             139441    1         2          12             2          3
# 5             139441    0         2          12             1          9
# 6             139441    1         3          12             1          3
# 7             139441    1         3          12             7          9
# 8             139441    0         2          12             7          3
# 9             139441    1         3          12             6         10
# 10            139441    0         2          12             5         10
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# ...

# %%
subset2 = df1.loc[20:60,['Type','Category','comment','like','share']]
subset2
# Out:
#      Type  Category  comment   like  share
# 20      1         2        3   66.0   12.0
# 21      1         1        0    0.0    0.0
# 22   Link         1        0   16.0    2.0
# 23      1         3        0   72.0   24.0
# 24      0         2        3   99.0   19.0
# 25      0         2        0   88.0   18.0
# 26      0         2       10  412.0   72.0
# 27      1         3        0  100.0   17.0
# 28      1         2       36  523.0   63.0
# 29  Video         1       18  143.0   13.0
# 30      1         2       33  107.0   22.0
# 31      1         2        1   27.0   11.0
# 32      1         3        2  155.0   47.0
# 33      1         3        4   98.0   23.0
# 34      1         1        2   56.0   17.0
# 35      1         2        6  172.0   21.0
# 36      1         3        0   96.0   17.0
# 37      1         1       16   76.0    8.0
# 38      0         2       11  227.0   31.0
# 39      1         1        1   44.0   14.0
# 40      0         2        7  216.0   39.0
# ...

# %%
subset3 = df1[['Type','Category','comment','like','share']]
subset3
# Out:
#     Type  Category  comment    like  share
# 0      1         2        4    79.0   17.0
# 1      0         2        5   130.0   29.0
# 2      1         3        0    66.0   14.0
# 3      1         2       58  1572.0  147.0
# 4      1         2       19   325.0   49.0
# ..   ...       ...      ...     ...    ...
# 494    1         3       10   125.0   41.0
# 495    1         3        5    53.0   26.0
# 496    1         2        0    53.0   22.0
# 497    1         1        4    93.0   18.0
# 498    1         3        7    91.0   38.0
#
# [495 rows x 5 columns]

# %%
subset4 = df1.iloc[100:200,[1,2,15,16,17]]
subset4
# Out:
#     Type  Category  comment    like  share
# 100    1         1        0     0.0    0.0
# 101    1         2       26  1505.0   95.0
# 102    1         3        2    63.0   14.0
# 103    1         1        0    13.0    4.0
# 104    1         1        4    59.0    9.0
# ..   ...       ...      ...     ...    ...
# 199    1         3       33  1155.0  102.0
# 200    1         2        2   139.0   25.0
# 201    1         1        0    40.0    5.0
# 202    0         2        2    53.0   15.0
# 203    1         3        4   220.0   19.0
#
# [100 rows x 5 columns]

# %%
subset5 = df1.iloc[100:200,[3,4,5,18]]
subset5
# Out:
#      Post Month  Post Weekday  Post Hour  Total Interactions
# 100          10             4          9                   0
# 101          10             4          3                1626
# 102          10             3         10                  79
# 103          10             3          4                  17
# 104          10             2         11                  72
# ..          ...           ...        ...                 ...
# 199           8             4         10                1290
# 200           8             4          3                 166
# 201           8             3          9                  45
# 202           8             3          2                  70
# 203           8             2         10                 243
#
# [100 rows x 4 columns]

# %%
subset6 = df1.iloc[100:200,[1,3,4,5,18]]
subset6
# Out:
#     Type  Post Month  Post Weekday  Post Hour  Total Interactions
# 100    1          10             4          9                   0
# 101    1          10             4          3                1626
# 102    1          10             3         10                  79
# 103    1          10             3          4                  17
# 104    1          10             2         11                  72
# ..   ...         ...           ...        ...                 ...
# 199    1           8             4         10                1290
# 200    1           8             4          3                 166
# 201    1           8             3          9                  45
# 202    0           8             3          2                  70
# 203    1           8             2         10                 243
#
# [100 rows x 5 columns]

# %%
merge1 = pd.concat([subset2, subset4])
merge1
# Out:
#      Type  Category  comment    like  share
# 20      1         2        3    66.0   12.0
# 21      1         1        0     0.0    0.0
# 22   Link         1        0    16.0    2.0
# 23      1         3        0    72.0   24.0
# 24      0         2        3    99.0   19.0
# ..    ...       ...      ...     ...    ...
# 199     1         3       33  1155.0  102.0
# 200     1         2        2   139.0   25.0
# 201     1         1        0    40.0    5.0
# 202     0         2        2    53.0   15.0
# 203     1         3        4   220.0   19.0
#
# [141 rows x 5 columns]

# %%
merge2 = pd.merge(subset4,subset5,left_index=True, right_index=True)
merge2
# Out:
#     Type  Category  comment    like  share  Post Month  Post Weekday  \
# 100    1         1        0     0.0    0.0          10             4
# 101    1         2       26  1505.0   95.0          10             4
# 102    1         3        2    63.0   14.0          10             3
# 103    1         1        0    13.0    4.0          10             3
# 104    1         1        4    59.0    9.0          10             2
# ..   ...       ...      ...     ...    ...         ...           ...
# 199    1         3       33  1155.0  102.0           8             4
# 200    1         2        2   139.0   25.0           8             4
# 201    1         1        0    40.0    5.0           8             3
# 202    0         2        2    53.0   15.0           8             3
# 203    1         3        4   220.0   19.0           8             2
#
#      Post Hour  Total Interactions
# 100          9                   0
# 101          3                1626
# ...

# %%
merging = pd.merge(subset4,subset5,left_on="share",right_on="Post Month")
merging
# Out:
#     Type  Category  comment  like  share  Post Month  Post Weekday  Post Hour  \
# 0      1         1        4  59.0    9.0           9             3          7
# 1      1         1        4  59.0    9.0           9             2         11
# 2      1         1        4  59.0    9.0           9             2          2
# 3      1         1        4  59.0    9.0           9             1         10
# 4      1         1        4  59.0    9.0           9             1          3
# ..   ...       ...      ...   ...    ...         ...           ...        ...
# 130    1         1        0  62.0   10.0          10             6          4
# 131    1         1        0  62.0   10.0          10             5         11
# 132    1         1        0  62.0   10.0          10             5          4
# 133    1         1        0  62.0   10.0          10             4         10
# 134    1         1        0  62.0   10.0          10             4          1
#
#      Total Interactions
# ...

# %%
merge3 = pd.merge(subset4,subset6,on="Type")
merge3
# Out:
#        Type  Category  comment   like  share  Post Month  Post Weekday  \
# 0         1         1        0    0.0    0.0          10             4
# 1         1         1        0    0.0    0.0          10             4
# 2         1         1        0    0.0    0.0          10             3
# 3         1         1        0    0.0    0.0          10             3
# 4         1         1        0    0.0    0.0          10             2
# ...     ...       ...      ...    ...    ...         ...           ...
# 7205   Link         1       15  143.0   44.0          10             6
# 7206   Link         1        0   24.0   11.0          10             5
# 7207   Link         1        0   24.0   11.0          10             4
# 7208   Link         1        0   24.0   11.0          10             6
# 7209  Video         1        6  345.0  121.0           9             2
#
#       Post Hour  Total Interactions
# 0             9                   0
# 1             3                1626
# ...

# %% [markdown]
# # Sorting

# %%
sort1 = df1.sort_values(by=['Post Weekday'],ascending=True)
sort1
# Out:
#      Page total likes Type  Category  Post Month  Post Weekday  Post Hour  \
# 357            116091    1         2           5             1          3
# 64             138185    1         1          11             1         10
# 145            136013    1         1          10             1         10
# 146            136013    1         3          10             1          3
# 325            121540    1         3           6             1          3
# ..                ...  ...       ...         ...           ...        ...
# 66             138185    1         1          11             7         11
# 67             138185    1         1          11             7          3
# 79             137177    1         1          11             7         12
# 299            124940    1         1           6             7          4
# 313            124940    1         3           6             7          3
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# ...

# %%
sort2 = df1.sort_values(by=['Post Weekday','Lifetime Post Total Reach'],ascending=[True,False])
sort2
# Out:
#      Page total likes Type  Category  Post Month  Post Weekday  Post Hour  \
# 379            111620    1         3           4             1         14
# 446             96749    1         1           3             1          2
# 323            123047    1         3           6             1         10
# 460             92507    1         3           2             1         13
# 206            132201    1         1           8             1          3
# ..                ...  ...       ...         ...           ...        ...
# 117            136642    1         1          10             7         11
# 125            136393    1         1          10             7          5
# 122            136393    1         1          10             7          8
# 123            136393    1         1          10             7          7
# 426            100732    1         1           3             7         18
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# ...

# %%
sort3 = df.sort_values(by=['share'],ascending=[True],na_position='first')
sort3
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 111            136736  Photo         1          10             6          8
# 120            136393  Photo         1          10             7          9
# 124            136393  Photo         1          10             7          6
# 164            135428  Photo         1           9             5         10
# 441             98195  Photo         1           3             5          4
# ..                ...    ...       ...         ...           ...        ...
# 105            137020  Photo         1          10             2          4
# 3              139441  Photo         2          12             2         10
# 460             92507  Photo         3           2             1         13
# 168            135428  Photo         1           9             3         10
# 244            130791  Photo         2           7             3          5
#
# ...

# %%
trans = df1.transpose()
trans
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                     1       0       1
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
df1.shape
# Out:
# (495, 19)

# %%
arr = subset2.to_numpy()
arr
# Out:
# array([[1, 2, 3, 66.0, 12.0],
#        [1, 1, 0, 0.0, 0.0],
#        ['Link', 1, 0, 16.0, 2.0],
#        [1, 3, 0, 72.0, 24.0],
#        [0, 2, 3, 99.0, 19.0],
#        [0, 2, 0, 88.0, 18.0],
#        [0, 2, 10, 412.0, 72.0],
#        [1, 3, 0, 100.0, 17.0],
#        [1, 2, 36, 523.0, 63.0],
#        ['Video', 1, 18, 143.0, 13.0],
#        [1, 2, 33, 107.0, 22.0],
#        [1, 2, 1, 27.0, 11.0],
#        [1, 3, 2, 155.0, 47.0],
#        [1, 3, 4, 98.0, 23.0],
#        [1, 1, 2, 56.0, 17.0],
#        [1, 2, 6, 172.0, 21.0],
#        [1, 3, 0, 96.0, 17.0],
#        [1, 1, 16, 76.0, 8.0],
#        [0, 2, 11, 227.0, 31.0],
#        [1, 1, 1, 44.0, 14.0],
#        [0, 2, 7, 216.0, 39.0],
#        ['Link', 1, 6, 187.0, 18.0],
#        [1, 1, 7, 26.0, 3.0],
#        ['Link', 1, 7, 29.0, 10.0],
#        [1, 1, 0, 47.0, 11.0],
#        ['Link', 1, 4, 57.0, 10.0],
#        [0, 1, 4, 174.0, 36.0],
#        ['Link', 1, 6, 18.0, 8.0],
#        [1, 1, 0, 77.0, 15.0],
# ...

# %%
arr.shape
# Out:
# (41, 5)

# %%
arr1 = arr.reshape(205,1)
arr1
# Out:
# array([[1],
#        [2],
#        [3],
#        [66.0],
#        [12.0],
#        [1],
#        [1],
#        [0],
#        [0.0],
#        [0.0],
#        ['Link'],
#        [1],
#        [0],
#        [16.0],
#        [2.0],
#        [1],
#        [3],
#        [0],
#        [72.0],
#        [24.0],
#        [0],
#        [2],
#        [3],
#        [99.0],
#        [19.0],
#        [0],
#        [2],
#        [0],
#        [88.0],
#        [18.0],
#        [0],
#        [2],
#        [10],
#        [412.0],
#        [72.0],
#        [1],
#        [3],
#        [0],
#        [100.0],
#        [17.0],
#        [1],
#        [2],
#        [36],
#        [523.0],
#        [63.0],
#        ['Video'],
#        [1],
#        [18],
#        [143.0],
#        [13.0],
#        [1],
#        [2],
#        [33],
#        [107.0],
#        [22.0],
#        [1],
#        [2],
#        [1],
#        [27.0],
#        [11.0],
#        [1],
#        [3],
#        [2],
#        [155.0],
# ...

# %%
df.pivot_table(index="like",columns="Total Interactions", aggfunc="sum")
# Out:
# C:\Users\Shubham\AppData\Local\Temp\ipykernel_14408\2840420801.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.pivot_table(index="like",columns="Total Interactions", aggfunc="sum")
#                    Category                                               ...  \
# Total Interactions     0    2    3    4    5    6    7    8    9    10    ...
# like                                                                      ...
# 0.0                     5.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 1.0                     NaN  NaN  NaN  1.0  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 2.0                     NaN  3.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 3.0                     NaN  NaN  2.0  NaN  NaN  1.0  NaN  NaN  NaN  NaN  ...
# ...

# %%
display(pd.concat([series1, series2],
                  axis = 1))

display(pd.concat([df1, df2],
                  keys = ['key1', 'key2']))

pandas.concat(objs, *, axis=0, join='outer', ignore_index=False, keys=None, levels=None, names=None, verify_integrity=False, sort=False, copy=None)


Join



DataFrame.join(other, on=None, how='left', lsuffix='', rsuffix='', sort=False, validate=None)


newdf = df1.join(df2)

df = pd.merge(a, b, on='id', how='inner')

df = pd.merge(a, b, on='id', how='left')
# Out:
#   Input In [26]
#     pandas.concat(objs, *, axis=0, join='outer', ignore_index=False, keys=None, levels=None, names=None, verify_integrity=False, sort=False, copy=None)
#                          ^
# SyntaxError: iterable argument unpacking follows keyword argument unpacking
