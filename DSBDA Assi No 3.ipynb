# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("cancer.csv")
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df3 = df[['diagnosis','radius_worst','texture_worst','perimeter_worst','area_worst','smoothness_worst','compactness_worst','concavity_worst','concave points_worst','symmetry_worst','fractal_dimension_worst']]
df2 = df[['diagnosis','radius_mean','texture_mean','perimeter_mean','area_mean','smoothness_mean','compactness_mean','concavity_mean']]

# %%
cor2 = df3.corr()
sns.heatmap(cor2,annot=True)
# Out:
# C:\Users\Shubham\AppData\Local\Temp\ipykernel_20524\494999216.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor2 = df3.corr()
# <AxesSubplot: >

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
cor = df2.corr()
cor
# Out:
# C:\Users\Shubham\AppData\Local\Temp\ipykernel_20524\390900050.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor = df2.corr()
#                   radius_mean  texture_mean  perimeter_mean  area_mean  \
# radius_mean          1.000000      0.323782        0.997855   0.987357
# texture_mean         0.323782      1.000000        0.329533   0.321086
# perimeter_mean       0.997855      0.329533        1.000000   0.986507
# area_mean            0.987357      0.321086        0.986507   1.000000
# smoothness_mean      0.170581     -0.023389        0.207278   0.177028
# compactness_mean     0.506124      0.236702        0.556936   0.498502
# concavity_mean       0.676764      0.302418        0.716136   0.685983
#
#                   smoothness_mean  compactness_mean  concavity_mean
# ...

# %%
sns.heatmap(cor,annot=True)
# Out:
# <AxesSubplot: >

# %%
corr = df.corr()
# Out:
# C:\Users\Shubham\AppData\Local\Temp\ipykernel_20524\658818363.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()

# %%
col = df.columns
print(col)
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
sns.countplot(x='diagnosis',label='Count',data=df)
# Out:
# <AxesSubplot: xlabel='diagnosis', ylabel='count'>

# %%
print(df['perimeter_mean'].mean())
print(df['perimeter_mean'].max())
# Out:
# 91.96903339191564
# 188.5

# %%
plt.boxplot(df['perimeter_mean'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2326e992520>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2326e9929d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2326e992280>],
#  'medians': [<matplotlib.lines.Line2D at 0x2326e992f10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2326e9a41f0>],
#  'means': []}

# %%
plt.boxplot(df['radius_mean'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2326ea09a90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2326ea09fd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2326ea097f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2326ea1a580>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2326ea1a820>],
#  'means': []}

# %%
plt.boxplot(df['radius_worst'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2326ea79460>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2326ea799a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2326ea791c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2326ea79f10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2326ea861f0>],
#  'means': []}

# %%
plt.boxplot(df['perimeter_worst'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2326eae73a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2326eae78e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2326eae7100>],
#  'medians': [<matplotlib.lines.Line2D at 0x2326eae7e20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2326eaf7100>],
#  'means': []}

# %%
sns.scatterplot(x='perimeter_mean', y='area_mean',hue='diagnosis',data=df)
# Out:
# <AxesSubplot: xlabel='perimeter_mean', ylabel='area_mean'>

# %%
sns.scatterplot(x='radius_mean', y='area_mean',hue='diagnosis',data=df)
# Out:
# <AxesSubplot: xlabel='radius_mean', ylabel='area_mean'>

# %%
sns.scatterplot(x='radius_mean', y='perimeter_mean',hue='diagnosis',data=df)
# Out:
# <AxesSubplot: xlabel='radius_mean', ylabel='perimeter_mean'>

# %%
sns.scatterplot(x='radius_mean', y='texture_mean',hue='diagnosis',data=df)
# Out:
# <AxesSubplot: xlabel='radius_mean', ylabel='texture_mean'>

# %%
sns.scatterplot(x='radius_mean', y='compactness_mean',hue='diagnosis',data=df)
# Out:
# <AxesSubplot: xlabel='radius_mean', ylabel='compactness_mean'>

# %%
sns.scatterplot(x='perimeter_se', y='area_se',hue='diagnosis',data=df)
# Out:
# <AxesSubplot: xlabel='perimeter_se', ylabel='area_se'>

# %%
sns.scatterplot(x='radius_se', y='texture_se',hue='diagnosis',data=df)
# Out:
# <AxesSubplot: xlabel='radius_se', ylabel='texture_se'>

# %%
sns.boxplot(x='diagnosis',y='radius_mean',data=df)
# Out:
# <AxesSubplot: xlabel='diagnosis', ylabel='radius_mean'>

# %%
sns.boxplot(x='diagnosis',y='perimeter_mean',data=df)
# Out:
# <AxesSubplot: xlabel='diagnosis', ylabel='perimeter_mean'>

# %%
sns.boxplot(x='diagnosis',y='area_mean',data=df)
# Out:
# <AxesSubplot: xlabel='diagnosis', ylabel='area_mean'>

# %%
sns.boxplot(x='diagnosis',y='texture_mean',data=df)
# Out:
# <AxesSubplot: xlabel='diagnosis', ylabel='texture_mean'>

# %%
sns.boxplot(x='diagnosis',y='radius_worst',data=df)
# Out:
# <AxesSubplot: xlabel='diagnosis', ylabel='radius_worst'>

# %%
sns.boxplot(x='diagnosis',y='perimeter_worst',data=df)
# Out:
# <AxesSubplot: xlabel='diagnosis', ylabel='perimeter_worst'>

# %%
sns.boxplot(x='diagnosis',y='area_worst',data=df)
# Out:
# <AxesSubplot: xlabel='diagnosis', ylabel='area_worst'>

# %%
sns.boxplot(x='diagnosis',y='texture_worst',data=df)
# Out:
# <AxesSubplot: xlabel='diagnosis', ylabel='texture_worst'>

# %%
sns.boxplot(x='diagnosis', y='radius_se',data=df)
# Out:
# <AxesSubplot: xlabel='diagnosis', ylabel='radius_se'>

# %%
sns.boxplot(x='diagnosis', y='texture_se',data=df)
# Out:
# <AxesSubplot: xlabel='diagnosis', ylabel='texture_se'>

# %%
sns.scatterplot(x='radius_mean', y='radius_worst',hue='diagnosis',data=df)
# Out:
# <AxesSubplot: xlabel='radius_mean', ylabel='radius_worst'>

# %%
sns.scatterplot(x='perimeter_worst', y='area_worst',hue='diagnosis',data=df)
# Out:
# <AxesSubplot: xlabel='perimeter_worst', ylabel='area_worst'>

# %%
sns.histplot(x='radius_mean', data=df,bins=40,hue='diagnosis')
plt.show()

# %%
sns.histplot(x='area_mean', data=df,bins=40,hue='diagnosis')
plt.show()

# %%
sns.histplot(x='texture_mean', data=df,bins=40,hue='diagnosis')
plt.show()

# %%
sns.histplot(x='perimeter_se', data=df,bins=40,hue='diagnosis')
plt.show()

# %%
sns.histplot(x='radius_se', data=df,bins=40,hue='diagnosis')
plt.show()

# %%
plt.figure(figsize=(200,30))
plt.xlabel('area-mean')
plt.ylabel('radius-mean')
sns.barplot(x='area_mean',y='radius_mean',hue='diagnosis',data=df)
# Out:
# <AxesSubplot: xlabel='area_mean', ylabel='radius_mean'>

# %%
plt.figure(figsize=(200,30))
plt.xlabel('perimeter-mean')
plt.ylabel('radius-mean')
sns.barplot(x='perimeter_mean',y='radius_mean',hue='diagnosis',data=df)
plt.show()

# %%
#hue maps the categorical variable with x and y of the plot
#M - Malignant B - Benign
#negative coorelation means both value moves in opposite direction
